# %%
import pickle
with open("exam_score_model.sav", "rb") as file:
    loaded_model = pickle.load(file)

# %%
loaded_model.predict([[6, 85, 7]])
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([78.40696977])
